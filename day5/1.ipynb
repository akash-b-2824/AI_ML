# %%
class baba:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def greet(self):
        print("Hello, I am Baba!",self.a,self.b)
c=baba("aku","kamu")
c.greet()
print(c.a)
# Out:
# aku

# %%
class babi:
    def add(self):
        a=int(input("Enter a number: "))
        b=int(input("Enter another number: "))
        print("The sum is:",a+b)
d=babi()
d.add()
# Out:
# The sum is: 11

# %%
class bankAccount:
    def __init__(self,owner,balance):
        self.owner=owner
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print("Deposit successful. New balance:",self.balance)
    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient funds.for ",amount,"Current balance:",self.balance,"Withdrawal failed.")
        else:
            self.balance-=amount
            print("Withdrawal successful. New balance:",self.balance)
    def balence(self):
        print("Current balance:",self.balance)
akash=bankAccount("akash",1000)
akash.deposit(500)
akash.withdraw(200)
akash.withdraw(1500)
akash.balence()
# Out:
# Deposit successful. New balance: 1500
# Withdrawal successful. New balance: 1300
# Insufficient funds.for  1500 Current balance: 1300 Withdrawal failed.
# Current balance: 1300

# %%
from baba import bank
print(bank.baba())
ak=bank.bankAccount("akash",1000)
ak.deposit(500)
ak.withdraw(200)
ak.withdraw(1500)
ak.balence()
# Out:
# Hello, I am Baba!
# None
# Deposit successful. New balance: 1500
# Withdrawal successful. New balance: 1300
# Insufficient funds.for  1500 Current balance: 1300 Withdrawal failed.
# Current balance: 1300

# %%
def  calc_rectangle(length, width):
    area=length*width
    perimeter=2*(length+width)
    return (area,perimeter)
length=float(input("Enter the length of the rectangle: "))
width=float(input("Enter the width of the rectangle: "))
area, perimeter=calc_rectangle(length, width)
print("Area of the rectangle:", area)
print("Perimeter of the rectangle:", perimeter)
# Out:
# Area of the rectangle: 2420.0
# Perimeter of the rectangle: 198.0

# %%
from math_operations import power, average
# Calculate 2^10
result_power = power(2, 10)
print(f"2^10 = {result_power}")

# Calculate average of [10, 20, 30, 40]
result_average = average([10, 20, 30, 40])
print(f"Average of [10, 20, 30, 40] = {result_average}")
# Out:
# 2^10 = 1024
# Average of [10, 20, 30, 40] = 25.0
